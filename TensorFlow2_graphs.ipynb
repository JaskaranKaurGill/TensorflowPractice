# %%
import tensorflow.compat.v1 as tf

# %%
# Launch the graph in a session.
with tf.Session() as ses:

    #get default graph
    graph = tf.get_default_graph()
    operations = graph.get_operations()
    print("operations are :", operations)
    # Build a graph.
    a = tf.constant(20)
    b = tf.constant(10)
    c = tf.add(a,b)
    d = tf.multiply(a,b)
    e = tf.multiply(c,d)
    

    # Evaluate the tensor `c`.
    print(ses.run(c))
    for op in graph.get_operations() : print(op)
# Out:
# operations are : [<tf.Operation 'Const' type=Const>, <tf.Operation 'Const_1' type=Const>, <tf.Operation 'mul' type=Mul>, <tf.Operation 'Const_2' type=Const>, <tf.Operation 'Const_3' type=Const>, <tf.Operation 'mul_1' type=Mul>, <tf.Operation 'Const_4' type=Const>, <tf.Operation 'Const_5' type=Const>, <tf.Operation 'mul_2' type=Mul>, <tf.Operation 'Const_6' type=Const>, <tf.Operation 'Const_7' type=Const>, <tf.Operation 'mul_3' type=Mul>, <tf.Operation 'Const_8' type=Const>, <tf.Operation 'Const_9' type=Const>, <tf.Operation 'mul_4' type=Mul>, <tf.Operation 'Const_10' type=Const>, <tf.Operation 'Const_11' type=Const>, <tf.Operation 'Add' type=Add>, <tf.Operation 'Mul_5' type=Mul>, <tf.Operation 'Mul_6' type=Mul>, <tf.Operation 'Const_12' type=Const>, <tf.Operation 'Const_13' type=Const>, <tf.Operation 'Add_1' type=Add>, <tf.Operation 'Mul_7' type=Mul>, <tf.Operation 'Mul_8' type=Mul>]
# 30
# name: "Const"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 5.0
#     }
#   }
# }
#
# name: "Const_1"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 6.0
#     }
#   }
# }
#
# name: "mul"
# op: "Mul"
# input: "Const"
# input: "Const_1"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "Const_2"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 5.0
#     }
#   }
# }
#
# name: "Const_3"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 6.0
#     }
#   }
# }
#
# name: "mul_1"
# op: "Mul"
# input: "Const_2"
# input: "Const_3"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "Const_4"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 5.0
#     }
#   }
# }
#
# name: "Const_5"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 6.0
#     }
#   }
# }
#
# name: "mul_2"
# op: "Mul"
# input: "Const_4"
# input: "Const_5"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "Const_6"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 5.0
#     }
#   }
# }
#
# name: "Const_7"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 6.0
#     }
#   }
# }
#
# name: "mul_3"
# op: "Mul"
# input: "Const_6"
# input: "Const_7"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "Const_8"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 5.0
#     }
#   }
# }
#
# name: "Const_9"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       float_val: 6.0
#     }
#   }
# }
#
# name: "mul_4"
# op: "Mul"
# input: "Const_8"
# input: "Const_9"
# attr {
#   key: "T"
#   value {
#     type: DT_FLOAT
#   }
# }
#
# name: "Const_10"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_INT32
#       tensor_shape {
#       }
#       int_val: 20
#     }
#   }
# }
#
# name: "Const_11"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_INT32
#       tensor_shape {
#       }
#       int_val: 10
#     }
#   }
# }
#
# name: "Add"
# op: "Add"
# input: "Const_10"
# input: "Const_11"
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
#
# name: "Mul_5"
# op: "Mul"
# input: "Const_10"
# input: "Const_11"
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
#
# name: "Mul_6"
# op: "Mul"
# input: "Add"
# input: "Mul_5"
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
#
# name: "Const_12"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_INT32
#       tensor_shape {
#       }
#       int_val: 20
#     }
#   }
# }
#
# name: "Const_13"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_INT32
#       tensor_shape {
#       }
#       int_val: 10
#     }
#   }
# }
#
# name: "Add_1"
# op: "Add"
# input: "Const_12"
# input: "Const_13"
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
#
# name: "Mul_7"
# op: "Mul"
# input: "Const_12"
# input: "Const_13"
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
#
# name: "Mul_8"
# op: "Mul"
# input: "Add_1"
# input: "Mul_7"
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
#
# name: "Const_14"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_INT32
#       tensor_shape {
#       }
#       int_val: 20
#     }
#   }
# }
#
# name: "Const_15"
# op: "Const"
# attr {
#   key: "dtype"
#   value {
#     type: DT_INT32
#   }
# }
# attr {
#   key: "value"
#   value {
#     tensor {
#       dtype: DT_INT32
#       tensor_shape {
#       }
#       int_val: 10
#     }
#   }
# }
#
# name: "Add_2"
# op: "Add"
# input: "Const_14"
# input: "Const_15"
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
#
# name: "Mul_9"
# op: "Mul"
# input: "Const_14"
# input: "Const_15"
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
#
# name: "Mul_10"
# op: "Mul"
# input: "Add_2"
# input: "Mul_9"
# attr {
#   key: "T"
#   value {
#     type: DT_INT32
#   }
# }
